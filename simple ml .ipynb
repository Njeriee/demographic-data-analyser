# %%
import pandas as pd
mydf = pd.read_csv(r'C:\Users\OpenCapital121\Desktop\vgsales.csv')
mydf.
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
mydf.describe()

# %%
mydf.values
#returns array
# Out:
# array([[1, 'Wii Sports', 'Wii', ..., 3.77, 8.46, 82.74],
#        [2, 'Super Mario Bros.', 'NES', ..., 6.81, 0.77, 40.24],
#        [3, 'Mario Kart Wii', 'Wii', ..., 3.79, 3.31, 35.82],
#        ...,
#        [16598, 'SCORE International Baja 1000: The Official Game', 'PS2',
#         ..., 0.0, 0.0, 0.01],
#        [16599, 'Know How 2', 'DS', ..., 0.0, 0.0, 0.01],
#        [16600, 'Spirits & Spells', 'GBA', ..., 0.0, 0.0, 0.01]],
#       dtype=object)

# %%
from sklearn.tree import DecisionTreeClassifier
music_data = pd.read_csv(r'C:\Users\OpenCapital121\Desktop\music.csv')
music_data
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %%
#splitting data set input and output sets
#input set
x = music_data.drop(columns = ['genre'])
#output set
y = music_data['genre']
# Out:
# 0        HipHop
# 1        HipHop
# 2        HipHop
# 3          Jazz
# 4          Jazz
# 5          Jazz
# 6     Classical
# 7     Classical
# 8     Classical
# 9         Dance
# 10        Dance
# 11        Dance
# 12     Acoustic
# 13     Acoustic
# 14     Acoustic
# 15    Classical
# 16    Classical
# 17    Classical
# Name: genre, dtype: object

# %%
#setting up a model
model = DecisionTreeClassifier()
#training the model using the input and output sets
model.fit(x,y)
#prediction for a 21 year old male and a 22 year old female
model.predict([[21,1],[22,0]])
# Out:
# array(['HipHop', 'Dance'], dtype=object)

# %%
#calculating the accuracy of the model
#first we split the data 80% data for training and 20% for testing
from sklearn.model_selection import train_test_split
# the train_test_split has the option called random_size() of ensuring that the split is done onceand will remain that way
train_test_split(x,y, test_size = 0.2,random_size(1))
#the above method returns a tuple of four data sets
#we can assigne variables to the tuples as
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.2)
#now we fit a model with only the training data
model.fit(x_train,y_train)
# for predictions we use x_test
prediction = model.predict(x_test)
prediction
# Out:
# DecisionTreeClassifier()

# %%
#storing models in files
from joblib import dump, load
dump(model,'music-recomender.joblib')
# Out:
# ['music-recomender.joblib']

# %%
#now to check the accuracy
from sklearn.metrics import accuracy_score
acc_score = accuracy_score(y_test, prediction)
acc_score
# Out:
# 1.0

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# C:\Users\OPENCA~1\AppData\Local\Temp/ipykernel_11424/698702891.py in <module>
#       1 #storing models in files
# ----> 2 from sklearn.externals import joblib
#       3 joblib.dump(model,'music-recomender.joblib')
#
# ImportError: cannot import name 'joblib' from 'sklearn.externals' (C:\Users\OpenCapital121\anaconda3\lib\site-packages\sklearn\externals\__init__.py)
