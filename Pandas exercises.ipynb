# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#creating a dataframe
pd.DataFrame(data= [None],index=[None],columns=[None])
# Out:
#       NaN
# NaN  None

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

# %%
#populating the data frame
marvel_df = pd.DataFrame(data = marvel_data)
marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
#naming the columns
col_names = ['name','sex','first appearance']
marvel_df.columns = col_names
marvel_df
# Out:
#                 name     sex  first appearance
# 0         Spider-Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %%
#making the character names the index
marvel_df.index = marvel_df['name']
marvel_df
# Out:
#                               name     sex  first appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# ...

# %%
marvel_df.drop(columns=['name'])
# Out:
#                      sex  first appearance
# name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
marvel_df.drop(['Namor','Hank Pym'])
# Out:
#                               name     sex  first appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# ...

# %%
#show the first 5 elements of marvel_df
marvel_df.head()
# Out:
#                             name   sex  first appearance
# name
# Spider-Man            Spider-Man  male              1962
# Captain America  Captain America  male              1941
# Wolverine              Wolverine  male              1974
# Iron Man                Iron Man  male              1963
# Thor                        Thor  male              1963

# %%
#showing the last 5 elements of marvel_df
marvel_df.tail()
marvel_df.shape
# Out:
# (20, 3)

# %%
#extracting the first five elements with column sex only
marvel_df.iloc[:5, ].sex.to_frame
# Out:
# <bound method Series.to_frame of name
# Spider-Man         male
# Captain America    male
# Wolverine          male
# Iron Man           male
# Thor               male
# Name: sex, dtype: object>

# %%
#extracting all the middle elements
marvel_df.iloc[1:19]
marvel_df
# Out:
#                               name     sex  first appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# ...

# %%
#Modify the first_appearance of 'Vision' to year 1964
marvel_df.loc['Vision','first appearance']=1964
marvel_df
# Out:
#                               name     sex  first appearance
# name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# ...

# %%
#Add a new column to marvel_df called 'years_since' with the years since first_appearance
marvel_df['years since']= 2022 - marvel_df['first appearance']
marvel_df
# Out:
#                               name     sex  first appearance  years since
# name
# Spider-Man              Spider-Man    male              1962           60
# Captain America    Captain America    male              1941           81
# Wolverine                Wolverine    male              1974           48
# Iron Man                  Iron Man    male              1963           59
# Thor                          Thor    male              1963           59
# Thing                        Thing    male              1961           61
# Mister Fantastic  Mister Fantastic    male              1961           61
# Hulk                          Hulk    male              1962           60
# Beast                        Beast    male              1963           59
# Invisible Woman    Invisible Woman  female              1961           61
# Storm                        Storm  female              1975           47
# Namor                        Namor    male              1939           83
# ...

# %%
#Given the marvel_df pandas DataFrame, make a mask showing the female characters
mask = marvel_df['sex']=='female'
mask
# Out:
# name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman      True
# Storm                True
# Namor               False
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Hank Pym            False
# Scarlet Witch        True
# Wasp                 True
# Black Widow          True
# Vision              False
# Name: sex, dtype: bool

# %%
#Given the marvel_df pandas DataFrame, get the male characters
mask2 = marvel_df['sex']=='male'
mask2
# Out:
# name
# Spider-Man           True
# Captain America      True
# Wolverine            True
# Iron Man             True
# Thor                 True
# Thing                True
# Mister Fantastic     True
# Hulk                 True
# Beast                True
# Invisible Woman     False
# Storm               False
# Namor                True
# Hawkeye              True
# Daredevil            True
# Doctor Strange       True
# Hank Pym             True
# Scarlet Witch       False
# Wasp                False
# Black Widow         False
# Vision               True
# Name: sex, dtype: bool

# %%
#Given the marvel_df pandas DataFrame, get the characters with first_appearance after 1970
marvel_df['first appearance']>1970
# Out:
# name
# Spider-Man          False
# Captain America     False
# Wolverine            True
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman     False
# Storm                True
# Namor               False
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Hank Pym            False
# Scarlet Witch       False
# Wasp                False
# Black Widow         False
# Vision              False
# Name: first appearance, dtype: bool

# %%
#Given the marvel_df pandas DataFrame, get the female characters with first_appearance after 1970
(marvel_df['sex'] == 'female') & (marvel_df['first appearance'] > 1970)
# Out:
# name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman     False
# Storm                True
# Namor               False
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Hank Pym            False
# Scarlet Witch       False
# Wasp                False
# Black Widow         False
# Vision              False
# dtype: bool

# %%
# Plot the values of first_appearance
marvel_df.plot('name','first appearance')
# Out:
# <AxesSubplot:xlabel='name'>

# %%
marvel_df.hist('first appearance')
# Out:
# array([[<AxesSubplot:title={'center':'first appearance'}>]], dtype=object)
